# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Install library roboflow (untuk running menggunakan colab harus install dahulu untuk setiap runtime)
# !pip install roboflow

# %%
# Install library ultralytics (untuk running menggunakan colab harus install dahulu untuk setiap runtime)
# !pip install ultralytics

# %%
# import library roboflow untuk import dataset dan ultralytics untuk penggunaan YOLO
from roboflow import Roboflow
from ultralytics import YOLO

# %%
rf = Roboflow(api_key="TOnENLnttgHdwOx2AJr8")
project = rf.workspace("project-arsan").project("lpr-with-new-dataset-2")
version = project.version(1)
dataset = version.download("coco-segmentation")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Load the YOLOv8 model for segmentation
model = YOLO('yolov8n-seg.yaml')

# %%
# Pre-trained weights can also be loaded if available
model = YOLO('yolov8n-seg.pt')
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 84.9MB/s]

# %%
# import pretrained model YOLO yang sebelumnya kedalam model YOLO telah dibuat menggunakan yaml
# model = YOLO('yolov8n.yaml').load('yolov8n.pt')
# Out:
# Transferred 355/355 items from pretrained weights

# %%
# Train the model using the segmentation dataset
model.train(data='/content/LPR-With-New-Dataset-2-1/data.yaml', epochs=100, imgsz=640, val=True, patience=50)
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# model = YOLO('/content/drive/MyDrive/Project/Dataset/last.pt')

# %%
model_eval = model.val()
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/LPR-With-New-Dataset-2-1/valid/labels.cache... 400 images, 0 backgrounds, 0 corrupt: 100%|██████████| 400/400 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:06<00:00,  3.65it/s]
#                    all        400        401      0.997      0.995      0.995      0.866
# Speed: 0.4ms preprocess, 5.2ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to runs/detect/train32

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Copy the model file to Google Drive
# !cp '/content/runs/detect/train3/weights/best.pt' '/content/drive/MyDrive/Project/Dataset'
# !cp '/content/runs/detect/train3/weights/last.pt' '/content/drive/MyDrive/Project/Dataset'
# Out:
# cp: cannot create regular file '/content/drive/MyDrive/Project/Dataset': No such file or directory
# cp: cannot create regular file '/content/drive/MyDrive/Project/Dataset': No such file or directory

# %%
model = YOLO('/content/lastv8n New.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-3053d5981bfa> in <cell line: 1>()
# ----> 1 model = YOLO('/content/lastv8n New.pt')
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      21         else:
#      22             # Continue with default YOLO initialization
# ---> 23             super().__init__(model=model, task=task, verbose=verbose)
#      24
#      25     @property
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     150             self._new(model, task=task, verbose=verbose)
#     151         else:
# --> 152             self._load(model, task=task)
#     153
#     154     def __call__(
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     239
# ...

# %%
model.predict('/content/drive/MyDrive/Project/Dataset/05 09 23/HP Nanta/169390321286963 (1).mp4', save=True, imgsz=640, conf=0.1, format='mp4')
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/73) /content/drive/MyDrive/Project/Dataset/05 09 23/HP Nanta/169390321286963 (1).mp4: 384x640 (no detections), 123.9ms
# video 1/1 (2/73) /content/drive/MyDrive/Project/Dataset/05 09 23/HP Nanta/169390321286963 (1).mp4: 384x640 (no detections), 71.7ms
# video 1/1 (3/73) /content/drive/MyDrive/Project/Dataset/05 09 23/HP Nanta/169390321286963 (1).mp4: 384x640 (no detections), 9.3ms
# ...
