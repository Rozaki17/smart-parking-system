# %%
# !pip install roboflow

# %%
# !pip install ultralytics

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# %%
rf = Roboflow(api_key="7om7lxUsuf1itU6s1mUW")
project = rf.workspace("keamanan-parkir").project("deteksi-wajah-keamanan-parkir")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.154, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Deteksi-Wajah-Keamanan-Parkir-1 in yolov8:: 100%|██████████| 3602/3602 [00:01<00:00, 2309.88it/s]

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd '/content/Deteksi-Wajah-Keamanan-Parkir-1'
# Out:
# /content/Deteksi-Wajah-Keamanan-Parkir-1

# %%
model = YOLO('yolov8n.yaml')  # build a new model from YAML
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 81.6MB/s]

# %%
model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Train the model
model.train(data='/content/Deteksi-Wajah-Keamanan-Parkir-1/data.yaml', epochs=150, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.154 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.predict('/content/drive/MyDrive/Colab Notebooks/Parking System/Salinan tes2.mp4', save=True, imgsz=640, conf=0.5)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1949) /content/drive/MyDrive/Colab Notebooks/Parking System/Salinan tes2.mp4: 384x640 (no detections), 31727.2ms
# video 1/1 (2/1949) /content/drive/MyDrive/Colab Notebooks/Parking System/Salinan tes2.mp4: 384x640 (no detections), 8665.2ms
# video 1/1 (3/1949) /content/drive/MyDrive/Colab Notebooks/Parking System/Salinan tes2.mp4: 384x640 (no detections), 17.1ms
# ...
